# %% [markdown]
# # Importing Python Libraries
#
#
# ---

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report

# %% [markdown]
# # Data Loading:
#
#
# ---
#
#
# Loading the given Dataset into pandas Dataframe

# %%
CreditCard_data = pd.read_csv('/content/drive/MyDrive/creditcard.csv')

# %% [markdown]
# # Data Visualisation
# ---

# %% [markdown]
# 1. Visualising the first 5 rows of the dataset:

# %%
CreditCard_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# 2. Visualising the last 5 rows of the dataset:

# %%
CreditCard_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [5 rows x 31 columns]

# %% [markdown]
# 3. Obtaining some general Information about the given Dataset:

# %%
CreditCard_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %% [markdown]
# # Data Preprocessing
# ---

# %% [markdown]
# **1. Missing values Handling:** Checking for missing values in each column of the Dataset (if any):

# %%
CreditCard_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# There are no missing values in our dataset.

# %% [markdown]
# **2. Handling Unbalanced Dataset:**
#
#
# ---
#
#
# Checking the distribution of legit and fradulent trasactions:

# %%
CreditCard_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# The Data is highly unbalanced.
#
# we have two label:
# *    label - '0' --> indicates legitmate transaction.
# *    label - '1' --> indicates fradulent transaction.
#
# There are 282315 legit trasanction and only 492 fraud transactions. Training our model on such a data will result in a **biased** model which will be biased towards the class - 'legit transaction' which is the majority class.

# %% [markdown]
# **Under-Sampling Method:**

# %% [markdown]
# 1. Separating the data into different classes for analysis

# %%
#1. Legit Class:
legit_class = CreditCard_data[CreditCard_data.Class == 0]
#2. Fraud Class:
fraud_class = CreditCard_data[CreditCard_data.Class == 1]

# %% [markdown]
# 2. Comparing the values of both the class

# %%
#Compare the values of transactions of both the classes:
CreditCard_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# **Dealing with unbalanced Dataset:** Using Undersampling Method
#
#
# ---
#
# Under this method, we build a new_dataset containing similar distribution of normal and fraudulent transactions.

# %% [markdown]
# 1. Obtaining n=492 random examples from the majority class:

# %%
#Creating a sample_ Data frame of legit transactions:
legit_sample_Dataset = legit_class.sample(n=492)

# %% [markdown]
# 2. Creating a new Dataset by concatenating equal number of positive and negative examples:

# %%
new_dataset = pd.concat([legit_sample_Dataset, fraud_class], axis=0)    #Combining both the Dataframe row-wise so, axis = 0;

# %% [markdown]
# **Visualising the New_Dataset:**
#
#
# ---
#
# 1. Observing the 1st 5 values of the new dataframe:

# %%
new_dataset.head()
# Out:
#            Time        V1        V2        V3        V4        V5        V6  \
# 50631   44574.0  0.992541 -0.360673  0.779725  0.332404 -0.168497  1.582743
# 32755   36953.0 -0.648418  1.011575  1.609446 -0.163771  0.091489 -0.215964
# 124236  77226.0 -0.854714  1.319893  0.567815  0.086617 -0.865264 -0.786654
# 18789   29764.0 -0.074249  0.768555  0.917003  1.045026 -0.400449  0.430726
# 7702    10705.0 -0.738028  0.041667  1.104943  0.463004  0.197646 -0.416251
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 50631  -0.931037  0.809374  0.444002  ...  0.058984  0.178059  0.234266
# 32755   0.536053  0.156052 -0.639123  ... -0.117211 -0.308669  0.050429
# 124236 -0.171514  0.820390 -0.841608  ...  0.162556  0.103024  0.140750
# 18789  -0.199727 -1.577401 -0.258991  ...  1.354629 -0.959747 -0.262985
# 7702   -0.005761 -0.429865  1.456986  ... -0.210937  0.243575  0.659375
#
#              V24       V25       V26       V27       V28  Amount  Class
# 50631  -1.060753 -0.260211  0.332002  0.046348 -0.003142    6.44      0
# 32755   0.209966 -0.321472  0.058291  0.147683  0.103853    2.68      0
# 124236  0.535508 -0.476346  0.115432 -0.361730 -0.101455   19.40      0
# 18789  -0.017595  0.797042 -0.363937  0.272973  0.205555   91.95      0
# 7702    0.015690 -1.644498  0.841557 -0.307373 -0.092950    1.86      0
#
# [5 rows x 31 columns]

# %% [markdown]
# 2. Checking for the distribution of classes in the new_dataset:

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %% [markdown]
# 3. Comparing the Statistical measures of both the classes in the new dataset:

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      92710.376016 -0.068043 -0.025029  0.052243  0.047956 -0.117163
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.075249  0.030250 -0.014490 -0.053314  ...  0.051865  0.005896
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.051251  0.020857  0.009709  0.019734  0.007789 -0.008314  0.003462
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0      113.753191
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# We can observe that the mean value in our new_dataset are similar with the original dataset, we can conclude that we got a **good sample**.

# %% [markdown]
# # Feature-Label Split over dataset:
#
#
# ---

# %% [markdown]
# 1. Obtaining all the features in 'X' variable
# 2. Obtaining all the features in 'Y' variable

# %%
X = new_dataset.drop(columns = 'Class',axis = 1)  #Features.
Y = new_dataset['Class']                          #Output Labels.

# %% [markdown]
# 3. Printing the features:

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 50631    44574.0  0.992541 -0.360673  0.779725  0.332404 -0.168497  1.582743
# 32755    36953.0 -0.648418  1.011575  1.609446 -0.163771  0.091489 -0.215964
# 124236   77226.0 -0.854714  1.319893  0.567815  0.086617 -0.865264 -0.786654
# 18789    29764.0 -0.074249  0.768555  0.917003  1.045026 -0.400449  0.430726
# 7702     10705.0 -0.738028  0.041667  1.104943  0.463004  0.197646 -0.416251
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 50631  -0.931037  0.809374  0.444002  ... -0.355819  0.058984  0.178059
# 32755   0.536053  0.156052 -0.639123  ...  0.063761 -0.117211 -0.308669
# 124236 -0.171514  0.820390 -0.841608  ... -0.325389  0.162556  0.103024
# 18789  -0.199727 -1.577401 -0.258991  ... -0.316972  1.354629 -0.959747
# 7702   -0.005761 -0.429865  1.456986  ... -0.365432 -0.210937  0.243575
# ...          ...       ...       ...  ...       ...       ...       ...
# 279863 -0.882850  0.697211 -2.064945  ...  1.252967  0.778584 -0.319189
# 280143 -1.413170  0.248525 -1.127396  ...  0.226138  0.370612  0.028234
# 280149 -2.234739  1.210158 -0.652250  ...  0.247968  0.751826  0.834108
# 281144 -2.208002  1.058733 -1.632333  ...  0.306271  0.583276 -0.269209
# 281674  0.223050 -0.068384  0.577829  ... -0.017652 -0.164350 -0.295135
#
#              V23       V24       V25       V26       V27       V28  Amount
# 50631   0.234266 -1.060753 -0.260211  0.332002  0.046348 -0.003142    6.44
# 32755   0.050429  0.209966 -0.321472  0.058291  0.147683  0.103853    2.68
# 124236  0.140750  0.535508 -0.476346  0.115432 -0.361730 -0.101455   19.40
# 18789  -0.262985 -0.017595  0.797042 -0.363937  0.272973  0.205555   91.95
# 7702    0.659375  0.015690 -1.644498  0.841557 -0.307373 -0.092950    1.86
# ...          ...       ...       ...       ...       ...       ...     ...
# 279863  0.639419 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00
# 280143 -0.145640 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76
# 280149  0.190944  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89
# 281144 -0.456108 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00
# 281674 -0.072173 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53
#
# [984 rows x 30 columns]

# %% [markdown]
# 4. Printing the output class labels:

# %%
print(Y)
# Out:
# 50631     0
# 32755     0
# 124236    0
# 18789     0
# 7702      0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# # Normalising the feature set:
# ---
# Standardization: Scaling the data such that their mean = 0 and standard deviation = 1

# %% [markdown]
# 1. Obtaining the Standard_scaler:

# %%
scaler_standard = StandardScaler()

# %% [markdown]
# 2. Scaling the feature set

# %%
X_standardized = scaler_standard.fit_transform(X)

# %% [markdown]
# 3. Converting the standardized features back to a data_frame

# %%
X = pd.DataFrame(X_standardized, columns=X.columns)
print("Standardized Data:")
print(X.head())
# Out:
# Standardized Data:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -0.869512  0.620890 -0.577782  0.685895 -0.613304  0.347117  1.268872
# 1 -1.026708  0.322328 -0.210725  0.819167 -0.768357  0.408689  0.251785
# 2 -0.196007  0.284793 -0.128254  0.651858 -0.690112  0.182104 -0.070914
# 3 -1.174994  0.426794 -0.275729  0.707945 -0.390612  0.292185  0.617459
# 4 -1.568119  0.306024 -0.470161  0.738132 -0.572492  0.433830  0.138532
#
#          V7        V8        V9  ...       V20       V21       V22       V23  \
# 0  0.311177  0.108379  0.763736  ... -0.480077 -0.107538  0.123199  0.190935
# 1  0.559531 -0.024891  0.294049  ... -0.125390 -0.170538 -0.289185  0.047074
# 2  0.439751  0.110626  0.206244  ... -0.454353 -0.070506  0.059625  0.117755
# 3  0.434975 -0.378493  0.458890  ... -0.447238  0.355730 -0.840817 -0.198188
# 4  0.467810 -0.144411  1.203007  ... -0.488204 -0.204051  0.178708  0.523604
#
#         V24       V25       V26       V27       V28    Amount
# 0 -1.812976 -0.423791  0.643555 -0.034578 -0.097599 -0.345032
# 1  0.461147 -0.513068  0.060831  0.066163  0.146923 -0.356663
# 2  1.043748 -0.738769  0.182482 -0.440269 -0.322278 -0.304943
# 3  0.053896  1.116961 -0.838083  0.190720  0.379346 -0.080525
# 4  0.113464 -2.441137  1.728384 -0.386230 -0.302842 -0.359199
#
# [5 rows x 30 columns]

# %% [markdown]
# # Train/Test Split Over Dataset:
# ---

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X,Y,test_size = 0.25,stratify=Y,random_state = 4)

# %% [markdown]
# # Training of Model: Logistic Regression
#
#
#
# ---

# %% [markdown]
# 1. Obtainign our model:

# %%
model =  LogisticRegression()

# %% [markdown]
# 2. Training our Logistic_Regression model on the Training set:

# %%
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Model Evaluation:
#
#
# ---

# %% [markdown]
# 1. Checking Accuracy Score on training data:

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)
print('Accuracy on Training Set: ' , training_data_accuracy)
# Out:
# Accuracy on Training Set:  0.9539295392953929

# %% [markdown]
# 2. Checking Accuracy Score on testing data:

# %%
X_test_prediction = model.predict(X_test)
testing_data_accuracy = accuracy_score(X_test_prediction,Y_test)
print('Accuracy on Testing Set : ' , testing_data_accuracy)
# Out:
# Accuracy on Testing Set :  0.943089430894309

# %% [markdown]
# 3. Checking Precision on training data and testing data:

# %%
precision_train = precision_score(Y_train, X_train_prediction, average='weighted')
precision_test = precision_score(Y_test, X_test_prediction, average='weighted')
print('Precision on Training Set: ', precision_train)
print('Precision on Testing Set: ', precision_test)
# Out:
# Precision on Training Set:  0.9558579488881513
# Precision on Testing Set:  0.944971788914703

# %% [markdown]
# 4. Checking Recall on the training data and testing data:

# %%
recall_train = recall_score(Y_train, X_train_prediction, average='weighted')
recall_test = recall_score(Y_test, X_test_prediction, average='weighted')
print('Recall on Training Set: ', recall_train)
print('Recall on Testing Set: ', recall_test)
# Out:
# Recall on Training Set:  0.9539295392953929
# Recall on Testing Set:  0.943089430894309

# %% [markdown]
# 5. Checking F1-Score on training and testing data:

# %%
f1_train = f1_score(Y_train, X_train_prediction, average='weighted')
f1_test = f1_score(Y_test, X_test_prediction, average='weighted')
print('F1-Score on Training Set: ', f1_train)
print('F1-Score on Testing Set: ', f1_test)
# Out:
# F1-Score on Training Set:  0.953880764904387
# F1-Score on Testing Set:  0.9430291801760073

# %% [markdown]
# **No Overfitting:**  As the model performs equally well on training and testing data, There is no overfitting
